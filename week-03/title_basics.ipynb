# %%
import numpy as np
import pandas as pd
import re

title_basics = pd.read_csv('~/greenfox/data-science/week-03/imdb/title.basics.tsv', sep='\t', low_memory=False)

# %%
import jupyternotify
ip = get_ipython()
ip.register_magics(jupyternotify.JupyterNotifyMagics)

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             \N           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
cols = ['runtimeMinutes', 'startYear', 'endYear', 'isAdult']

# %%
title_basics[cols] = title_basics[cols].replace('\\N', np.nan)

# %%
title_basics.drop(title_basics.loc[title_basics.runtimeMinutes.str.isnumeric() == False].index, inplace=True)

# %%
title_basics.runtimeMinutes = title_basics.runtimeMinutes.astype(float)

# %%
title_basics.drop(title_basics.loc[(title_basics['isAdult'] != 0) & (title_basics['isAdult'] != 1)].index, inplace=True)

# %%
title_basics.tconst.is_unique
# Out:
# True

# %%
regex = re.compile(r'^tt\d{7}')

# %%
title_basics.tconst.str.match(regex).all()
# Out:
# True

# %%
title_basics.titleType.unique()
# Out:
# array(['short', 'movie', 'tvMovie', 'tvSeries', 'tvEpisode', 'tvShort',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
title_basics.drop(columns='originalTitle', inplace=True)

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle  isAdult startYear endYear  \
# 0  tt0000001     short              Carmencita        0      1894     NaN
# 1  tt0000002     short  Le clown et ses chiens        0      1892     NaN
# 2  tt0000003     short          Pauvre Pierrot        0      1892     NaN
# 3  tt0000004     short             Un bon bock        0      1892     NaN
# 4  tt0000005     short        Blacksmith Scene        0      1893     NaN
#
#    runtimeMinutes                    genres
# 0             1.0         Documentary,Short
# 1             5.0           Animation,Short
# 2             4.0  Animation,Comedy,Romance
# 3             NaN           Animation,Short
# 4             1.0              Comedy,Short

# %%
title_basics.startYear.describe()
# Out:
# count     5263192
# unique        145
# top          2017
# freq       304998
# Name: startYear, dtype: object

# %%
max = title_basics.loc[:, 'startYear'].dropna().max()

# %%
max
# Out:
# '2115'

# %%
min = title_basics.loc[:, 'startYear'].dropna().min()

# %%
min
# Out:
# '1874'

# %%
title_basics.loc[title_basics['startYear'] == '2115']
# Out:
#             tconst titleType primaryTitle  isAdult startYear endYear  \
# 3504889  tt5174640     movie    100 Years        0      2115     NaN
#
#          runtimeMinutes genres
# 3504889             NaN  Drama

# %%
title_basics.drop(title_basics[title_basics['startYear'] > '2019'].index, inplace=True)

# %%
title_basics.endYear.unique()
# Out:
# array([nan, '1947', '1950', '1949', '1958', '1951', '1952', '1954',
#        '1957', '1953', '1956', '1967', '1971', '1959', '1955', '1963',
#        '1960', '1961', '1965', '1980', '2016', '1986', '1962', '1972',
#        '1966', '1970', '2009', '1987', '1991', '1974', '1992', '1976',
#        '1975', '1982', '2010', '1984', '1964', '1968', '1989', '1994',
#        '1973', '1969', '2004', '1981', '1977', '1999', '1988', '2003',
#        '1978', '2001', '2013', '1993', '1997', '1996', '2011', '2005',
#        '1995', '1979', '2006', '1985', '1983', '1998', '1990', '2008',
#        '2007', '2015', '2014', '2000', '2018', '2002', '2012', '2019',
#        '1948', '2017', '1938', '1942', '1933', '1946', '1945', '2020',
#        '1941', '1937', '1939', '1932', '2025', '1936', '1924', '1927',
#        '1935', '2024', '2027', '2021', '2022'], dtype=object)

# %%
title_basics[title_basics['endYear'].isnull()].shape
# Out:
# (5526293, 8)

# %%
title_basics.loc[(title_basics['runtimeMinutes'] > 300) & (title_basics['titleType'] != 'tvSeries')].shape
# Out:
# (2215, 8)

# %%
# %%notify
# import time
# time.sleep(5)

# %%
# %%notify
#
# def extr_categories(row):
#     cats = row.genres.split(',')
#     for cat in cats:
#         if cat not in categories:
#             categories.append(cat)
#     return row
#
# categories = []
# title_basics.apply(extr_categories, axis='columns')
# Out:
#             tconst     titleType  \
# 0        tt0000001         short
# 1        tt0000002         short
# 2        tt0000003         short
# 3        tt0000004         short
# 4        tt0000005         short
# 5        tt0000006         short
# 6        tt0000007         short
# 7        tt0000008         short
# 8        tt0000009         movie
# 9        tt0000010         short
# 10       tt0000011         short
# 11       tt0000012         short
# 12       tt0000013         short
# 13       tt0000014         short
# 14       tt0000015         short
# 15       tt0000016         short
# 16       tt0000017         short
# 17       tt0000018         short
# 18       tt0000019         short
# 19       tt0000020         short
# 20       tt0000022         short
# 21       tt0000023         short
# 22       tt0000024         short
# 23       tt0000025         short
# 24       tt0000026         short
# 25       tt0000027         short
# 26       tt0000028         short
# ...

# %%
categories
# Out:
# ['Documentary',
#  'Short',
#  'Animation',
#  'Comedy',
#  'Romance',
#  'Sport',
#  'News',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Biography',
#  'Music',
#  'War',
#  'Crime',
#  'Western',
#  'Family',
#  'Adventure',
#  'History',
#  'Sci-Fi',
#  'Action',
#  'Mystery',
#  '\\N',
#  'Thriller',
#  'Musical',
#  'Film-Noir',
#  'Game-Show',
#  'Talk-Show',
#  'Reality-TV',
#  'Adult']

# %%
title_basics['genres'] = title_basics['genres'].replace('\\N', '')

# %%
title_basics.loc[title_basics['genres'] == '\\N']
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []
